# %%
import pandas as pd
import json

# %%
with open('JSON_files/cwc_results.json') as f:
    data = json.load(f)

df_match = pd.DataFrame(data[0]['matchSummary'])
df_match.head()
# Out:
#        team1         team2     winner     margin        ground     matchDate  \
# 0      India     Australia  Australia  6 wickets     Ahmedabad  Nov 19, 2023
# 1  Australia  South Africa  Australia  3 wickets  Eden Gardens  Nov 16, 2023
# 2      India   New Zealand      India    70 runs      Wankhede  Nov 15, 2023
# 3      India   Netherlands      India   160 runs     Bengaluru  Nov 12, 2023
# 4    England      Pakistan    England    93 runs  Eden Gardens  Nov 11, 2023
#
#     scorecard
# 0  ODI # 4705
# 1  ODI # 4704
# 2  ODI # 4703
# 3  ODI # 4702
# 4  ODI # 4701

# %%
df_match.shape
# Out:
# (48, 7)

# %% [markdown]
# ## Preprocessing

# %%
df_match.rename({'scorecard':'matchid'}, inplace=True, axis=1)
df_match.head()
# Out:
#        team1         team2     winner     margin        ground     matchDate  \
# 0      India     Australia  Australia  6 wickets     Ahmedabad  Nov 19, 2023
# 1  Australia  South Africa  Australia  3 wickets  Eden Gardens  Nov 16, 2023
# 2      India   New Zealand      India    70 runs      Wankhede  Nov 15, 2023
# 3      India   Netherlands      India   160 runs     Bengaluru  Nov 12, 2023
# 4    England      Pakistan    England    93 runs  Eden Gardens  Nov 11, 2023
#
#       matchid
# 0  ODI # 4705
# 1  ODI # 4704
# 2  ODI # 4703
# 3  ODI # 4702
# 4  ODI # 4701

# %%
match_ids_dict = {}

for index, row in df_match.iterrows():
    key1 = row['team1'] + ' Vs ' + row['team2']
    key2 = row['team2'] + ' Vs ' + row['team1']
    match_ids_dict[key1] = row['matchid']
    match_ids_dict[key2] = row['matchid']

# %%
df_match.to_csv('CSV_files/cwc_results.csv', index = False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7152\3219869933.py in <module>
# ----> 1 df_match.to_csv('CSV_files/cwc_results.csv', index = False)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     331                     stacklevel=find_stack_level(),
#     332                 )
# --> 333             return func(*args, **kwargs)
#     334
#     335         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3962         )
#    3963
# -> 3964         return DataFrameRenderer(formatter).to_csv(
#    3965             path_or_buf,
#    3966             lineterminator=lineterminator,
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1012             formatter=self.fmt,
#    1013         )
# -> 1014         csv_formatter.save()
#    1015
#    1016         if created_buffer:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     249         """
#     250         # apply compression and byte/text conversion
# --> 251         with get_handle(
#     252             self.filepath_or_buffer,
#     253             self.mode,
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747     # Only for write methods
#     748     if "r" not in mode and is_path:
# --> 749         check_parent_directory(str(handle))
#     750
#     751     if compression:
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in check_parent_directory(path)
#     614     parent = Path(path).parent
#     615     if not parent.is_dir():
# --> 616         raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#     617
#     618
#
# OSError: Cannot save file into a non-existent directory: 'CSV_files'

# %%
with open('JSON_files/batting_summary.json') as f:
    data = json.load(f)
    all_records = []
    for rec in data:
        all_records.extend(rec['battingSummary'])
  
df_batting = pd.DataFrame(all_records)
df_batting.head(11)
# Out:
#                  match teamInnings  battingPos       batsmanName  \
# 0   India Vs Australia       India           1   Rohit Sharma(c)
# 1   India Vs Australia       India           2      Shubman Gill
# 2   India Vs Australia       India           3       Virat Kohli
# 3   India Vs Australia       India           4      Shreyas Iyer
# 4   India Vs Australia       India           5       KL Rahulâ€
# 5   India Vs Australia       India           6   Ravindra Jadeja
# 6   India Vs Australia       India           7  Suryakumar Yadav
# 7   India Vs Australia       India           8    Mohammed Shami
# 8   India Vs Australia       India           9    Jasprit Bumrah
# 9   India Vs Australia       India          10     Kuldeep Yadav
# 10  India Vs Australia       India          11    Mohammed Siraj
#
#                         dismissal runs balls 4s 6s      SR
# 0                c Head b Maxwell   47    31  4  3  151.61
# 1                 c Zampa b Starc    4     7  0  0   57.14
# 2                       b Cummins   54    63  4  0   85.71
# 3           c â€ Inglis b Cummins    4     3  1  0  133.33
# 4             c â€ Inglis b Starc   66   107  1  0   61.68
# 5         c â€ Inglis b Hazlewood    9    22  0  0   40.90
# 6         c â€ Inglis b Hazlewood   18    28  1  0   64.28
# 7             c â€ Inglis b Starc    6    10  1  0   60.00
# 8                     lbw b Zampa    1     3  0  0   33.33
# 9   run out (Labuschagne/Cummins)   10    18  0  0   55.55
# 10                            NaN    9     8  1  0  112.50

# %%
df_batting['out/not_out'] = df_batting['dismissal'].apply(lambda x: "Not Out" if pd.isna(x) else "Out")
df_batting.head(11)
# Out:
#                  match teamInnings  battingPos       batsmanName  \
# 0   India Vs Australia       India           1   Rohit Sharma(c)
# 1   India Vs Australia       India           2      Shubman Gill
# 2   India Vs Australia       India           3       Virat Kohli
# 3   India Vs Australia       India           4      Shreyas Iyer
# 4   India Vs Australia       India           5       KL Rahulâ€
# 5   India Vs Australia       India           6   Ravindra Jadeja
# 6   India Vs Australia       India           7  Suryakumar Yadav
# 7   India Vs Australia       India           8    Mohammed Shami
# 8   India Vs Australia       India           9    Jasprit Bumrah
# 9   India Vs Australia       India          10     Kuldeep Yadav
# 10  India Vs Australia       India          11    Mohammed Siraj
#
#                         dismissal runs balls 4s 6s      SR out/not_out
# 0                c Head b Maxwell   47    31  4  3  151.61         Out
# 1                 c Zampa b Starc    4     7  0  0   57.14         Out
# 2                       b Cummins   54    63  4  0   85.71         Out
# 3           c â€ Inglis b Cummins    4     3  1  0  133.33         Out
# 4             c â€ Inglis b Starc   66   107  1  0   61.68         Out
# 5         c â€ Inglis b Hazlewood    9    22  0  0   40.90         Out
# 6         c â€ Inglis b Hazlewood   18    28  1  0   64.28         Out
# 7             c â€ Inglis b Starc    6    10  1  0   60.00         Out
# 8                     lbw b Zampa    1     3  0  0   33.33         Out
# 9   run out (Labuschagne/Cummins)   10    18  0  0   55.55         Out
# 10                            NaN    9     8  1  0  112.50     Not Out

# %%
df_batting.drop(columns="dismissal", inplace=True)
df_batting
# Out:
#                          match teamInnings  battingPos          batsmanName  \
# 0           India Vs Australia       India           1      Rohit Sharma(c)
# 1           India Vs Australia       India           2         Shubman Gill
# 2           India Vs Australia       India           3          Virat Kohli
# 3           India Vs Australia       India           4         Shreyas Iyer
# 4           India Vs Australia       India           5          KL Rahulâ€
# ..                         ...         ...         ...                  ...
# 871  South Africa Vs Sri Lanka   Sri Lanka           7     Dasun Shanaka(c)
# 872  South Africa Vs Sri Lanka   Sri Lanka           8     Dunith Wellalage
# 873  South Africa Vs Sri Lanka   Sri Lanka           9        Kasun Rajitha
# 874  South Africa Vs Sri Lanka   Sri Lanka          10  Matheesha Pathirana
# 875  South Africa Vs Sri Lanka   Sri Lanka          11   Dilshan Madushanka
#
#     runs balls 4s 6s      SR out/not_out
# 0     47    31  4  3  151.61         Out
# 1      4     7  0  0   57.14         Out
# 2     54    63  4  0   85.71         Out
# 3      4     3  1  0  133.33         Out
# 4     66   107  1  0   61.68         Out
# ..   ...   ... .. ..     ...         ...
# 871   68    62  6  3  109.67         Out
# 872    0     1  0  0    0.00         Out
# 873   33    31  4  1  106.45         Out
# 874    5    16  1  0   31.25         Out
# 875    4     2  1  0  200.00     Not Out
#
# [876 rows x 10 columns]

# %%
df_batting['batsmanName'] = df_batting['batsmanName'].apply(lambda x: x.replace('â€', ''))
df_batting['batsmanName'] = df_batting['batsmanName'].apply(lambda x: x.replace('\xa0', ''))
df_batting.head()
# Out:
#                 match teamInnings  battingPos      batsmanName runs balls 4s  \
# 0  India Vs Australia       India           1  Rohit Sharma(c)   47    31  4
# 1  India Vs Australia       India           2     Shubman Gill    4     7  0
# 2  India Vs Australia       India           3      Virat Kohli   54    63  4
# 3  India Vs Australia       India           4     Shreyas Iyer    4     3  1
# 4  India Vs Australia       India           5         KL Rahul   66   107  1
#
#   6s      SR out/not_out
# 0  3  151.61         Out
# 1  0   57.14         Out
# 2  0   85.71         Out
# 3  0  133.33         Out
# 4  0   61.68         Out
